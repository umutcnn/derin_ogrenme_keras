# %% [markdown]
# # Gradyan
# Görüntü gradyanı, görüntüdeki yoğunluk veya renkteki yönlü bir değişikliktir.
# Kenar algılamada kullanılır.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread("img/sudoku.png",0)
plt.figure(),plt.imshow(img, cmap="gray"),plt.axis("off"),plt.title("orijinal"),plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1e00cfd8f40>,
#  (-0.5, 224.5, 224.5, -0.5),
#  Text(0.5, 1.0, 'orijinal'),
#  None)

# %%
#x gradyan
sobelx= cv2.Sobel(img,cv2.CV_16S,1,0,ksize=5)
plt.figure(),plt.imshow(sobelx, cmap="gray"),plt.axis("off"),plt.title("sobelx"),plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1e00f43a100>,
#  (-0.5, 224.5, 224.5, -0.5),
#  Text(0.5, 1.0, 'sobelx'),
#  None)

# %%
#y gradyan
sobely= cv2.Sobel(img,cv2.CV_16S,0,1,ksize=5)
plt.figure(),plt.imshow(sobely, cmap="gray"),plt.axis("off"),plt.title("sobely"),plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1e00f4a17c0>,
#  (-0.5, 224.5, 224.5, -0.5),
#  Text(0.5, 1.0, 'sobely'),
#  None)

# %%
#laplacian gradian
laplacian=cv2.Laplacian(img,ddepth=cv2.CV_16S)
plt.figure(),plt.imshow(laplacian, cmap="gray"),plt.axis("off"),plt.title("laplacian"),plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1e00f500f10>,
#  (-0.5, 224.5, 224.5, -0.5),
#  Text(0.5, 1.0, 'laplacian'),
#  None)

# %%
#kütüphaneleri import edelim
import cv2
import matplotlib.pyplot as plt
import numpy as np


#resmi al 
img = cv2.imread("img/london.jpg", 0)
plt.figure(),plt.imshow(img,cmap="gray")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1fae2b636a0>)

# %%
edges=cv2.Canny(image=img, threshold1=0, threshold2=255)
plt.figure(),plt.imshow(edges,cmap="gray")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1fae5226e80>)

# %%
#medyan değerini alıp ona göre thresholdun max ve min değerlerini guncelleyecegim
med_val= np.median(img) #medyan
print(med_val, " + ", mean_val )
# Out:
# 140.0  +  127.25324166666667

# %%
low = int(max(0,1-0.33)*med_val)
hight = int(min(255,(1+0.33))*med_val)
print(low, " - ", hight )
# Out:
# 93  -  186

# %%
edges=cv2.Canny(image=img, threshold1=low, threshold2=hight)
plt.figure(),plt.imshow(edges,cmap="gray")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1fae5439fd0>)

# %%
#resme blur uygulayacagım denizdeki detayları yok etmek istiyorum
blurred_img= cv2.blur(img, ksize=(4,4))#buradaki ksize ile oynayarak kenarları optimize edebiliriz
plt.figure(),plt.imshow(blurred_img,cmap="gray")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1fae68affd0>)

# %%
med_val= np.median(blurred_img) #medyan
low = int(max(0,1-0.33)*med_val)
hight = int(min(255,(1+0.33))*med_val)
print(low, " - ", hight )
# Out:
# 93  -  184

# %%
edges=cv2.Canny(image=blurred_img, threshold1=0, threshold2=255)
plt.figure(),plt.imshow(edges,cmap="gray")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1fae6a84fd0>)
